# %%
import numpy as np
from statsmodels import regression
import statsmodels.api as sm
import matplotlib.pyplot as plt
import math
from utils import *

# %%
datadir = "/root/codespace/quant-finance-lectures/amarstock_adjusted_data/daily"
print(get_top20_stocks(path=datadir))
# Out:
# [('00DS30', 3084026774000.0), ('00DSES', 2132060774800.0), ('00DSEX', 3370925421616.0), ('1JANATAMF', 233585572.0), ('1STPRIMFMF', 332978314.0), ('AAMRANET', 148017730.0), ('AAMRATECH', 683394625.0), ('ABB1STMF', 256367920.0), ('ABBANK', 769581974.0), ('ACFL', 104802917.0), ('ACI', 94419722.0), ('ACIFORMULA', 126512844.0), ('ACMELAB', 53292422.0), ('ACTIVEFINE', 848206734.0), ('ADNTEL', 51799485.0), ('ADVENT', 237026778.0), ('AFCAGRO', 336544932.0), ('AFTABAUTO', 297630571.0), ('AGNISYSL', 567261957.0), ('AGRANINS', 25712648.0)]

# %%
stockname1 = '00DS30'
stockname2 = 'AAMRANET'
df1 = get_prices(stockname1, path=datadir) 
df2 = get_prices(stockname2, path=datadir) 
returns1 = get_returns(dataframe=df1, field='close')
returns2 = get_returns(dataframe=df2, field='close')
linreg(returns1.values, returns2.values)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                 0.0005866
# Date:                Tue, 18 Oct 2022   Prob (F-statistic):              0.981
# Time:                        17:22:10   Log-Likelihood:                 8611.9
# No. Observations:                2620   AIC:                        -1.722e+04
# Df Residuals:                    2618   BIC:                        -1.721e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.000     -1.653      0.098      -0.001    5.43e-05
# x1             0.0008      0.032      0.024      0.981      -0.062       0.063
# ==============================================================================
# Omnibus:                      991.580   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           131170.458
# Skew:                           0.737   Prob(JB):                         0.00
# Kurtosis:                      37.632   Cond. No.                         180.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
